# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ayush\anaconda3\lib\site-packages (0.2.14)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (2.3.6)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (2023.2)
# Requirement already satisfied: requests>=2.26 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ayush\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayush\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\ayush\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\ayush\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\ayush\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ayush\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ayush\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ayush\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: pycparser in c:\users\ayush\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stocks = input("Enter the code of the stock:- ")
data = yf.download(stocks,"2008-01-01","2023-02-20",auto_adjust=True)
data.head()
# Out:
# Enter the code of the stock:- TSLA
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  103003500

# %%
data.shape
# Out:
# (3183, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3183 entries, 2010-06-29 to 2023-02-17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3183 non-null   float64
#  1   High    3183 non-null   float64
#  2   Low     3183 non-null   float64
#  3   Close   3183 non-null   float64
#  4   Volume  3183 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 149.2 KB

# %%
data.Close.plot(figsize=(10,7),color="r")
plt.ylabel("{} Prices".format(stocks))
plt.title("{} Price series".format(stocks))
plt.show()

# %%
sns.distplot(data["Close"])
# Out:
# C:\Users\ayush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
sns.distplot(data["Open"])
# Out:
# C:\Users\ayush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Open', ylabel='Density'>

# %%
sns.distplot(data["High"])
# Out:
# C:\Users\ayush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='High', ylabel='Density'>

# %%
X =data.drop("Close",axis=1)
y= data["Close"]

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (2546, 4)
# (637, 4)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
pred1=lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score


def calculate_metrics(y_test,y_pred):
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    r2_scor = r2_score(y_test,y_pred)
    
    print("MSE:- ",mse)
    print("RMSE:- ",rmse)
    print("R2_score", r2_scor)

# %%
calculate_metrics(y_test,pred1)
# Out:
# MSE:-  2.305422217141241
# RMSE:-  1.5183616885120754
# R2_score 0.9997444501534508

# %%
from sklearn.linear_model import Lasso,Ridge

la= Lasso().fit(X_train,y_train)
ri = Ridge().fit(X_train,y_train)

la_p = la.predict(X_test)
ri_p = ri.predict(X_test)
# Out:
# C:\Users\ayush\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.653e+03, tolerance: 2.336e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
calculate_metrics(y_test,la_p)
# Out:
# MSE:-  5.86577323550575
# RMSE:-  2.4219358446304375
# R2_score 0.9993497948275675

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV


svr = SVR()

param_grid = {
    'C':[0.1,1,10,100,1000],
    "gamma":[1,0.1,0.01,0.001,0.0001],
    "kernel":["rbf"]
    }
grid = GridSearchCV(SVR(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.229 total time=   0.5s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.229 total time=   0.5s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.229 total time=   0.5s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.191 total time=   0.6s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.229 total time=   0.5s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.191 total time=   0.6s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.229 total time=   0.6s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.230 total time=   0.5s
# [CV 3/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.230 total time=   0.5s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.232 total time=   0.6s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.230 total time=   0.6s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.230 total time=   0.6s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.191 total time=   0.5s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.230 total time=   0.5s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.184 total time=   0.5s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.201 total time=   0.5s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.232 total time=   0.5s
# [CV 1/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.183 total time=   0.6s
# [CV 2/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.222 total time=   0.6s
# [CV 3/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.175 total time=   0.6s
# [CV 4/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.194 total time=   0.5s
# [CV 5/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.225 total time=   0.6s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.183 total time=   0.6s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.222 total time=   0.6s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.175 total time=   0.6s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.194 total time=   0.6s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.225 total time=   0.6s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.183 total time=   0.5s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.222 total time=   0.6s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.175 total time=   0.6s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.194 total time=   0.5s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.225 total time=   0.5s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.183 total time=   0.6s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.222 total time=   0.6s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.175 total time=   0.6s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.194 total time=   0.7s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.225 total time=   0.6s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.183 total time=   0.6s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.222 total time=   0.6s
# [CV 3/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.175 total time=   0.6s
# [CV 4/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.194 total time=   0.6s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.225 total time=   0.6s
# [CV 1/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.037 total time=   0.7s
# [CV 2/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.061 total time=   0.7s
# [CV 3/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.023 total time=   0.8s
# [CV 4/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.038 total time=   0.8s
# [CV 5/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.063 total time=   1.0s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.036 total time=   1.0s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.9s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.023 total time=   0.7s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.038 total time=   0.7s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.063 total time=   0.7s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.036 total time=   0.7s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.6s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.023 total time=   0.7s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.038 total time=   0.6s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.063 total time=   0.7s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.036 total time=   0.7s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.061 total time=   0.7s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.023 total time=   0.8s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.037 total time=   0.7s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.062 total time=   0.6s
# [CV 1/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.035 total time=   0.7s
# [CV 2/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.061 total time=   0.6s
# [CV 3/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.023 total time=   0.7s
# [CV 4/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.037 total time=   0.7s
# [CV 5/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.062 total time=   0.7s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.001 total time=   0.7s
# [CV 2/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.002 total time=   0.7s
# [CV 3/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.005 total time=   0.8s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.003 total time=   0.8s
# [CV 5/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.001 total time=   0.7s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.001 total time=   0.8s
# [CV 2/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.002 total time=   0.7s
# [CV 3/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.005 total time=   0.7s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.003 total time=   0.7s
# [CV 5/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.000 total time=   0.7s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.002 total time=   0.8s
# [CV 2/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.002 total time=   0.7s
# [CV 3/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.005 total time=   0.8s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.004 total time=   0.7s
# [CV 5/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.000 total time=   0.7s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.003 total time=   0.8s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.001 total time=   0.7s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.8s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.005 total time=   0.9s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.001 total time=   0.8s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.003 total time=   1.3s
# [CV 2/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.001 total time=   0.8s
# [CV 3/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.005 total time=   0.8s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.005 total time=   0.7s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.001 total time=   0.8s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
svr = SVR(C=10,gamma=0.01,kernel="rbf")
svr.fit(X_train,y_train)
svr_pred = svr.predict(X_test)

# %%
import joblib
joblib.dump(ri,"model.pkl")

ridge_from_joblib = model = joblib.load("model.pkl")
